# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.python.keras.layers import Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
import pathlib
from tensorflow.keras.layers import Dense,Dropout,Flatten
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import cv2
from PIL import ImageFile

# %%
train_dir = r'P:\Risk Realm\Artificial Intelligence\Project\dataset\train'
val_dir=r'P:\Risk Realm\Artificial Intelligence\Project\dataset\val'
test_dir=r'P:\Risk Realm\Artificial Intelligence\Project\dataset\testing'

# %%
print(train_dir)
# Out:
# P:\Risk Realm\Artificial Intelligence\Project\dataset\train

# %%
img_height,img_width=224,224
batch_size=16

def apply_clahe(image):
    # Convert image from float (0-1) to uint8 (0-255)
    image = (image * 255).astype(np.uint8)
    
    # Apply CLAHE to each channel (for RGB images)
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    channels = cv2.split(image)
    clahe_channels = [clahe.apply(channel) for channel in channels]
    image = cv2.merge(clahe_channels)
    
    # Normalize the image to make min value 0 and max value 1
    image = image.astype(np.float32)
    min_val = image.min()
    max_val = image.max()
    
    # Avoid division by zero
    if max_val - min_val != 0:
        image = (image - min_val) / (max_val - min_val)
    
    return image

train_datagen = ImageDataGenerator(
    preprocessing_function=apply_clahe
)

# Load training dataset with augmentation
train_ds = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary',        # Binary classification
    seed=123
)
test_datagen = ImageDataGenerator(preprocessing_function=apply_clahe)
test_ds=test_datagen.flow_from_directory(
    test_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary',        # Binary classification
    seed=123
)
val_datagen = ImageDataGenerator(preprocessing_function=apply_clahe)  # Note the absence of augmentation
val_ds = val_datagen.flow_from_directory(
    val_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary',    
    seed=123
)
# Out:
# Found 8683 images belonging to 2 classes.
# Found 175 images belonging to 2 classes.
# Found 600 images belonging to 2 classes.

# %%
class_names = train_ds.class_indices
print(class_names)
# Out:
# {'fractured': 0, 'not fractured': 1}

# %%
import matplotlib.pyplot as plt

# Get a batch of images and labels
images, labels = next(train_ds)

# Initialize counters for each class
fracture_count = 0
no_fracture_count = 0

# List to store selected images and labels
selected_images = []
selected_labels = []

# Loop through the batch to select 3 images of each class
for img, label in zip(images, labels):
    if label == 1 and fracture_count < 3:
        selected_images.append(img)
        selected_labels.append(label)
        fracture_count += 1
    elif label == 0 and no_fracture_count < 3:
        selected_images.append(img)
        selected_labels.append(label)
        no_fracture_count += 1
    
    # Stop if we have 3 of each class
    if fracture_count == 3 and no_fracture_count == 3:
        break

# Plot the selected images
plt.figure(figsize=(10, 10))
for i in range(6):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(selected_images[i])
    plt.title("Fracture" if selected_labels[i] == 0 else "No Fracture")
    plt.axis("off")

plt.show()

# %%
images, labels = next(train_ds)


min_val = images.min()
max_val = images.max()

print(f"Minimum pixel value: {min_val}")
print(f"Maximum pixel value: {max_val}")
# Out:
# Minimum pixel value: 0.0
# Maximum pixel value: 1.0

# %%
densenet_model = Sequential()


pretrained_model = DenseNet121(
    include_top=False,
    input_shape=(224, 224, 3),
    pooling='avg',
    weights='imagenet'
)


for layer in pretrained_model.layers:
    layer.trainable = False


densenet_model.add(pretrained_model)
densenet_model.add(Dense(512, activation='relu',kernel_regularizer=tf.keras.regularizers.l2(0.001)))
densenet_model.add(Dropout(0.5))
densenet_model.add(Dense(1, activation='sigmoid'))

# %%
densenet_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ densenet121 (Functional)        │ (None, 1024)           │     7,037,504 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           513 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,562,817 (28.85 MB)
#  Trainable params: 525,313 (2.00 MB)
#  Non-trainable params: 7,037,504 (26.85 MB)

# %%
for layer in pretrained_model.layers[-20:]:  # Unfreeze the last 20 layers
    layer.trainable = True


densenet_model.compile(
    optimizer=Adam(learning_rate=0.00001),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
history = densenet_model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=50
)
# Out:
# Epoch 1/50
# c:\Dev_Dynasty\Anaconda\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 324s 577ms/step - accuracy: 0.5451 - loss: 1.4183 - val_accuracy: 0.7600 - val_loss: 1.1479
# Epoch 2/50
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 298s 549ms/step - accuracy: 0.6680 - loss: 1.2075 - val_accuracy: 0.7217 - val_loss: 1.0658
# Epoch 3/50
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 294s 542ms/step - accuracy: 0.7391 - loss: 1.0589 - val_accuracy: 0.7200 - val_loss: 0.9967
# Epoch 4/50
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 290s 535ms/step - accuracy: 0.8076 - loss: 0.9179 - val_accuracy: 0.7000 - val_loss: 0.9701
# Epoch 5/50
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 295s 544ms/step - accuracy: 0.8553 - loss: 0.7928 - val_accuracy: 0.6750 - val_loss: 0.9732
# Epoch 6/50
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 345s 635ms/step - accuracy: 0.9121 - loss: 0.6692 - val_accuracy: 0.6550 - val_loss: 1.0125
# Epoch 7/50
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 374s 689ms/step - accuracy: 0.9377 - loss: 0.5817 - val_accuracy: 0.6933 - val_loss: 1.0043
# Epoch 8/50
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 410s 755ms/step - accuracy: 0.9565 - loss: 0.5149 - val_accuracy: 0.6867 - val_loss: 1.0431
# Epoch 9/50
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 414s 763ms/step - accuracy: 0.9626 - loss: 0.4745 - val_accuracy: 0.6933 - val_loss: 1.0711
# Epoch 10/50
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 400s 736ms/step - accuracy: 0.9747 - loss: 0.4285 - val_accuracy: 0.6867 - val_loss: 1.1130
# Epoch 11/50
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 402s 740ms/step - accuracy: 0.9871 - loss: 0.3916 - val_accuracy: 0.7067 - val_loss: 1.1324
# Epoch 12/50
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 383s 706ms/step - accuracy: 0.9802 - loss: 0.3774 - val_accuracy: 0.6950 - val_loss: 1.2215
# Epoch 13/50
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 365s 673ms/step - accuracy: 0.9880 - loss: 0.3563 - val_accuracy: 0.6983 - val_loss: 1.2473
# Epoch 14/50
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 389s 717ms/step - accuracy: 0.9921 - loss: 0.3346 - val_accuracy: 0.6900 - val_loss: 1.2881
# Epoch 15/50
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 389s 717ms/step - accuracy: 0.9934 - loss: 0.3214 - val_accuracy: 0.7100 - val_loss: 1.3109
# Epoch 16/50
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 410s 756ms/step - accuracy: 0.9938 - loss: 0.3103 - val_accuracy: 0.6883 - val_loss: 1.4249
# Epoch 17/50
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 377s 694ms/step - accuracy: 0.9913 - loss: 0.3067 - val_accuracy: 0.6900 - val_loss: 1.4561
# Epoch 18/50
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 361s 665ms/step - accuracy: 0.9938 - loss: 0.2942 - val_accuracy: 0.7083 - val_loss: 1.4470
# Epoch 19/50
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 393s 724ms/step - accuracy: 0.9963 - loss: 0.2826 - val_accuracy: 0.7183 - val_loss: 1.4003
# Epoch 20/50
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 395s 728ms/step - accuracy: 0.9921 - loss: 0.2812 - val_accuracy: 0.7017 - val_loss: 1.4849
# Epoch 21/50
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 394s 726ms/step - accuracy: 0.9979 - loss: 0.2652 - val_accuracy: 0.7117 - val_loss: 1.4930
# Epoch 22/50
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 402s 740ms/step - accuracy: 0.9968 - loss: 0.2579 - val_accuracy: 0.7233 - val_loss: 1.5118
# Epoch 23/50
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 385s 708ms/step - accuracy: 0.9954 - loss: 0.2548 - val_accuracy: 0.7133 - val_loss: 1.5571
# Epoch 24/50
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 329s 606ms/step - accuracy: 0.9967 - loss: 0.2444 - val_accuracy: 0.7217 - val_loss: 1.5099
# Epoch 25/50
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 321s 591ms/step - accuracy: 0.9982 - loss: 0.2359 - val_accuracy: 0.7233 - val_loss: 1.4910
# Epoch 26/50
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 320s 589ms/step - accuracy: 0.9987 - loss: 0.2307 - val_accuracy: 0.7250 - val_loss: 1.5241
# Epoch 27/50
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 316s 583ms/step - accuracy: 0.9974 - loss: 0.2271 - val_accuracy: 0.7267 - val_loss: 1.5448
# Epoch 28/50
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 318s 585ms/step - accuracy: 0.9964 - loss: 0.2235 - val_accuracy: 0.7350 - val_loss: 1.4928
# Epoch 29/50
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 319s 587ms/step - accuracy: 0.9982 - loss: 0.2145 - val_accuracy: 0.7150 - val_loss: 1.5858
# Epoch 30/50
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 328s 604ms/step - accuracy: 0.9980 - loss: 0.2107 - val_accuracy: 0.7050 - val_loss: 1.6784
# Epoch 31/50
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 323s 594ms/step - accuracy: 0.9971 - loss: 0.2073 - val_accuracy: 0.7333 - val_loss: 1.6296
# Epoch 32/50
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 364s 671ms/step - accuracy: 0.9983 - loss: 0.2005 - val_accuracy: 0.7083 - val_loss: 1.6302
# Epoch 33/50
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 407s 749ms/step - accuracy: 0.9992 - loss: 0.1942 - val_accuracy: 0.7333 - val_loss: 1.5101
# Epoch 34/50
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 445s 820ms/step - accuracy: 0.9988 - loss: 0.1903 - val_accuracy: 0.7117 - val_loss: 1.6329
# Epoch 35/50
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 426s 784ms/step - accuracy: 0.9995 - loss: 0.1850 - val_accuracy: 0.7250 - val_loss: 1.6493
# Epoch 36/50
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 395s 728ms/step - accuracy: 0.9990 - loss: 0.1814 - val_accuracy: 0.6883 - val_loss: 1.7575
# Epoch 37/50
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 426s 784ms/step - accuracy: 0.9980 - loss: 0.1795 - val_accuracy: 0.7033 - val_loss: 1.7600
# Epoch 38/50
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 416s 766ms/step - accuracy: 0.9986 - loss: 0.1738 - val_accuracy: 0.6933 - val_loss: 1.7917
# Epoch 39/50
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 441s 813ms/step - accuracy: 0.9986 - loss: 0.1683 - val_accuracy: 0.7233 - val_loss: 1.7399
# Epoch 40/50
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 397s 730ms/step - accuracy: 0.9996 - loss: 0.1642 - val_accuracy: 0.7350 - val_loss: 1.6957
# Epoch 41/50
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 397s 732ms/step - accuracy: 0.9981 - loss: 0.1609 - val_accuracy: 0.7317 - val_loss: 1.6524
# Epoch 42/50
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 444s 818ms/step - accuracy: 0.9990 - loss: 0.1566 - val_accuracy: 0.7417 - val_loss: 1.7282
# Epoch 43/50
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 437s 805ms/step - accuracy: 0.9986 - loss: 0.1526 - val_accuracy: 0.6883 - val_loss: 1.7666
# Epoch 44/50
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 429s 790ms/step - accuracy: 0.9990 - loss: 0.1489 - val_accuracy: 0.7067 - val_loss: 1.7814
# Epoch 45/50
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 362s 666ms/step - accuracy: 0.9986 - loss: 0.1465 - val_accuracy: 0.7250 - val_loss: 1.7331
# Epoch 46/50
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 365s 673ms/step - accuracy: 0.9967 - loss: 0.1467 - val_accuracy: 0.7050 - val_loss: 1.7670
# Epoch 47/50
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 372s 685ms/step - accuracy: 0.9976 - loss: 0.1412 - val_accuracy: 0.7000 - val_loss: 1.8782
# Epoch 48/50
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 385s 709ms/step - accuracy: 0.9994 - loss: 0.1359 - val_accuracy: 0.7117 - val_loss: 1.8065
# Epoch 49/50
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 420s 774ms/step - accuracy: 0.9994 - loss: 0.1328 - val_accuracy: 0.7300 - val_loss: 1.7277
# Epoch 50/50
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 424s 782ms/step - accuracy: 0.9996 - loss: 0.1290 - val_accuracy: 0.7267 - val_loss: 1.6124

# %%
import pickle

# Save the training history
with open('DenseNet(50).pkl', 'wb') as file:
    pickle.dump(history.history, file)

# %%
fig1 = plt.gcf()
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.axis(ymin=0.4,ymax=1)
plt.grid()
plt.title('Model Accuracy: DenseNet121')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'validation'])
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.grid()
plt.title('Model Loss: DenseNet121')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'validation'])
plt.show()

# %%
import numpy as np
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Get predictions on test set
val_preds = densenet_model.predict(val_ds)
val_preds = (val_preds > 0.5).astype(int)  # Convert probabilities to binary classes (0 or 1)

# Get the true labels from the test set
val_labels = np.concatenate([val_ds[i][1] for i in range(len(val_ds))])

# Calculate accuracy
accuracy = accuracy_score(val_labels, val_preds)
print(f"Accuracy: {accuracy:.2f}")

# Generate classification report
target_names = ['Not Fractured', 'Fractured']
report = classification_report(val_labels, val_preds, target_names=target_names)
print("Classification Report:\n", report)

# Generate and display the confusion matrix
conf_matrix = confusion_matrix(val_labels, val_preds)
print("Confusion Matrix:\n", conf_matrix)

# Plot confusion matrix using seaborn heatmap
plt.figure(figsize=(6, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=target_names, yticklabels=target_names)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()
# Out:
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 35s 842ms/step
# Accuracy: 0.50
# Classification Report:
#                 precision    recall  f1-score   support
#
# Not Fractured       0.60      0.53      0.56       360
#     Fractured       0.40      0.46      0.43       240
#
#      accuracy                           0.50       600
#     macro avg       0.50      0.50      0.49       600
#  weighted avg       0.52      0.50      0.51       600
#
# Confusion Matrix:
#  [[191 169]
#  [129 111]]

# %%
# Save the model in the SavedModel format
densenet_model.save('densenet_model(50).keras')
